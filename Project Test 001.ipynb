# %%
# For Creating Accounts...
class Account: 
    def __init__(self, account_name, account_type):
        self.account_name = account_name
        self.account_type = account_type
        self.balance = 0.0
        self.transactions = []
        
        # will add Menu...
    
    def debit(self, amount):
        self.balance += amount
        self.transactions.append(("Debit", amount))

    def credit(self, amount):
        self.balance -= amount
        self.transactions.append(("Credit", amount))

    def __str__(self):
        return f"{self.account_name} ({self.account_type}): Balance = {self.balance}"




# cash_account = Account("Cash", "Asset")
# bank_account = Account(input("Account"), input("Type") )
# sales_account = Account("Sales", "Income")

# %%
# For Journal Entries

class JournalEntry:
    def __init__(self, date, description):
        self.date = date
        self.description = description
        self.debits = []
        self.credits = []

    def add_debit(self, account, amount):
        account.debit(amount)
        self.debits.append((account.account_name, amount))
    
    def add_credit(self, account, amount):

        account.credit(amount)
        self.credits.append((account.account_name, amount))

    def print_entry(self):
        print(f"Date: {self.date} | Description: {self.description}")
        print("Debits:")
        for account, amount in self.debits:
            print(f"  {account} : {amount}")
        print("Credits:")
        for account, amount in self.credits:
            print(f"  {account} : {amount}")


# Creating journal entry
entry = JournalEntry("2025-09-30", "Sale of goods")
# entry.add_debit(cash_account, 1000)
# entry.add_credit(sales_account, 1000)
# entry.add_credit(tax_account, calculate_sales_tax(1000))
# Out:
# ok

# %%
# For Trial Balance

class TrialBalance:
    def __init__(self):
        self.accounts = {}

    def add_account(self, account):
        self.accounts[account.account_name] = account

    def print_trial_balance(self):
        total_debits = 0
        total_credits = 0
        print("Trial Balance:")
        for account in self.accounts.values():
            print(account)
            if account.balance > 0:
                total_debits += account.balance
            else:
                total_credits += abs(account.balance)
        
        print(f"Total Debits: {total_debits}")
        print(f"Total Credits: {total_credits}")
        if total_debits == total_credits:
            print("Trial Balance: Balanced")
        else:

            print("Trial Balance: Not Balanced")


# Trial Balance
trial_balance = TrialBalance()
trial_balance.add_account(cash_account)
trial_balance.add_account(sales_account)
# trial_balance.add_account(tax_account)

# Print Trial Balance
trial_balance.print_trial_balance()

# %%
# For Finanacial Statement

class FinancialStatements:
    def __init__(self, trial_balance):
        self.trial_balance = trial_balance

    def generate_income_statement(self):
        revenue = sum(account.balance for account in self.trial_balance.accounts.values() if 'Income' in account.account_type)
        expenses = sum(account.balance for account in self.trial_balance.accounts.values() if 'Expense' in account.account_type)
        profit_loss = revenue - expenses
        print("Income Statement:")
        print(f"Revenue: {revenue}")
        print(f"Expenses: {expenses}")
        print(f"Profit/Loss: {profit_loss}")


    def generate_balance_sheet(self):
        assets = sum(account.balance for account in self.trial_balance.accounts.values() if 'Asset' in account.account_type)
        liabilities = sum(account.balance for account in self.trial_balance.accounts.values() if 'Liability' in account.account_type)
        equity = sum(account.balance for account in self.trial_balance.accounts.values() if 'Equity' in account.account_type)
        print("Balance Sheet:")
        print(f"Assets: {assets}")
        print(f"Liabilities: {liabilities}")
        print(f"Equity: {equity}")

# Income Statement
financial_statements = FinancialStatements(trial_balance)
financial_statements.generate_income_statement()

# Balance Sheet
financial_statements.generate_balance_sheet()

# %%
# Creating Accounts
cash_account = Account("Cash", "Asset")
# bank_account = Account(input("Account"), input("Type") )
sales_account = Account("Sales", "Income")

# Creating journal entry
entry = JournalEntry("2025-09-30", "Sale of goods")
entry.add_debit(cash_account, 1000)
entry.add_credit(sales_account, 1000)
# entry.add_credit(tax_account, calculate_sales_tax(1000))

# Trial Balance
trial_balance = TrialBalance()
trial_balance.add_account(cash_account)
trial_balance.add_account(sales_account)
# trial_balance.add_account(tax_account)

# Print Trial Balance
trial_balance.print_trial_balance()

# Income Statement
financial_statements = FinancialStatements(trial_balance)
financial_statements.generate_income_statement()

# Balance Sheet
financial_statements.generate_balance_sheet()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Creating Accounts
# ----> 2 cash_account = Account("Cash", "Asset")
#       3 # bank_account = Account(input("Account"), input("Type") )
#       4 sales_account = Account("Sales", "Income")
#
# NameError: name 'Account' is not defined

# %%
# For Creating Accounts...
class Account:
    def __init__(self, account_name, account_type):
        self.account_name = account_name
        self.account_type = account_type
        self.balance = 0.0
        self.transactions = []
        self.Menu()
    print(f"Ok bhai")

    def Menu(self):
        user_input = input("""
        Press 1 for Create Account
        Press 2 for Journal Entry
        Press 3 for Trial Balance
        Press 4 for Income Statement
        Press 5 for Balance Sheet
        -------------------------
        Press any other key to exit
        """)

        if user_input == "1":
            self.CreatAccount()
        elif user_input == "2":
            self.CreatJournalEntry()
        elif user_input == "3":
            self.ViewTrialBalance()
        elif user_input == "4":
            self.ViewIncomeStatement()
        elif user_input == "5":
            self.ViewBalanceSheet()
        else:
            exit()
        
    def CreatAccount(self):
        
        def debit(self, amount):
            self.balance += amount
            self.transactions.append(("Debit", amount))
    
        def credit(self, amount):
            self.balance -= amount
            self.transactions.append(("Credit", amount))
            # if self.debit == self.credit:
            
        def __str__(self):
            return f"{self.account_name} ({self.account_type}): Balance = {self.balance}"
            # else:
            #     print(f"not saved as Dr. & Cr. are not equal")
            self.Menu()

# For Journal Entries

class JournalEntry:
    def __init__(self, date, description):
        self.date = date
        self.description = description
        self.debits = []
        self.credits = []
        self.Menu()
    print("ok")

    def CreatJournalEntry(self):

        def add_debit(self, account, amount):
            account.debit(amount)
            self.debits.append((account.account_name, amount))
        
        def add_credit(self, account, amount):
            account.credit(amount)
            self.credits.append((account.account_name, amount))
    
        def print_entry(self):
            print(f"Date: {self.date} | Description: {self.description}")
            print("Debits:")
            for account, amount in self.debits:
                print(f"  {account} : {amount}")
            print("Credits:")
            for account, amount in self.credits:
                print(f"  {account} : {amount}")
                self.Menu()

# For Trial Balance

class TrialBalance:
    def __init__(self):
        self.accounts = {}
        self.Menu()

    def ViewTrialBalance(self):
        
        def add_account(self, account):
            self.accounts[account.account_name] = account
    
        def print_trial_balance(self):
            total_debits = 0
            total_credits = 0
            print("Trial Balance:")
            for account in self.accounts.values():
                print(account)
                if account.balance > 0:
                    total_debits += account.balance
                else:
                    total_credits += abs(account.balance)
            
            print(f"Total Debits: {total_debits}")
            print(f"Total Credits: {total_credits}")
            if total_debits == total_credits:
                print("Trial Balance: Balanced")
            else:
                print("Trial Balance: Not Balanced")
                self.Menu()


# For Finanacial Statement

class FinancialStatements:
    def __init__(self, trial_balance):
        self.trial_balance = trial_balance

    def ViewIncomeStatement(self):
        
        def generate_income_statement(self):
            revenue = sum(account.balance for account in self.trial_balance.accounts.values() if 'Income' in account.account_type)
            expenses = sum(account.balance for account in self.trial_balance.accounts.values() if 'Expense' in account.account_type)
            profit_loss = revenue - expenses
            print("Income Statement:")
            print(f"Revenue: {revenue}")
            print(f"Expenses: {expenses}")
            print(f"Profit/Loss: {profit_loss}")
            self.Menu()
    
    def ViewBalanceSheet(self):
        
        def generate_balance_sheet(self):
            assets = sum(account.balance for account in self.trial_balance.accounts.values() if 'Asset' in account.account_type)
            liabilities = sum(account.balance for account in self.trial_balance.accounts.values() if 'Liability' in account.account_type)
            equity = sum(account.balance for account in self.trial_balance.accounts.values() if 'Equity' in account.account_type)
            print("Balance Sheet:")
            print(f"Assets: {assets}")
            print(f"Liabilities: {liabilities}")
            print(f"Equity: {equity}")
            self.Menu()


# Creating Accounts
cash_account = Account("Cash", "Asset")
# bank_account = Account(input("Account"), input("Type") )
sales_account = Account("Sales", "Income")

# Creating journal entry
# entry.print_entry()
entry.add_debit(cash_account, 2000)
entry.add_credit(sales_account, 1000)
entry.print_entry()
entry = JournalEntry("2025-09-30", "Sale of goods")
# entry = JournalEntry("ddffgg", "iiujll")
# entry.add_debit(input("account"), int(input("Amt.")))
# entry.add_credit(input("account"), int(input("Amt.")))

# Trial Balance
trial_balance = TrialBalance()
trial_balance.add_account(cash_account)
trial_balance.add_account(sales_account)
# trial_balance.add_account(account_name)
# tb = TrialBalance()
# Print Trial Balance
trial_balance.print_trial_balance()

# Income Statement
financial_statements = FinancialStatements(trial_balance)
financial_statements.generate_income_statement()

# Balance Sheet
financial_statements.generate_balance_sheet()
# Out:
# Ok bhai
# ok
#         Press 1 for Create Account
#         Press 2 for Journal Entry
#         Press 3 for Trial Balance
#         Press 4 for Income Statement
#         Press 5 for Balance Sheet
#         -------------------------
#         Press any other key to exit
#          2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 147
#     143             self.Menu()
#     146 # Creating Accounts
# --> 147 cash_account = Account("Cash", "Asset")
#     148 # bank_account = Account(input("Account"), input("Type") )
#     149 sales_account = Account("Sales", "Income")
#
# Cell In[1], line 8, in Account.__init__(self, account_name, account_type)
#       6 self.balance = 0.0
#       7 self.transactions = []
# ----> 8 self.Menu()
#
# Cell In[1], line 25, in Account.Menu(self)
#      23     self.CreatAccount()
#      24 elif user_input == "2":
# ---> 25     self.CreatJournalEntry()
#      26 elif user_input == "3":
#      27     self.ViewTrialBalance()
#
# AttributeError: 'Account' object has no attribute 'CreatJournalEntry'
